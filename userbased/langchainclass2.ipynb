# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# language  models =are the when you  give input and it return in text only .
#
# embedding models  = are when you give it text and it provides  in vectors from (for eg :semantic  layer)

# %% [markdown]
# ![image.png](attachment:image.png)
